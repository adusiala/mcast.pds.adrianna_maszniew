# %% [markdown]
# ## **Exercise Error Handling**

# %% [markdown]
# Write a function that asks the user for an integer input and prints it. Use try/except to catch a ValueError if the input is not an integer, printing an error message instead.

# %%
def ask():
    try:
        number = int(input("Enter a number: "))
    except ValueError:
        print("Error: Thtat is not a number")

ask()
# Out:
# Error: Thtat is not a number

# %% [markdown]
# Modify the previous function to also handle a KeyboardInterrupt exception, which occurs when the user cancels the input, printing a different error message.

# %%
def ask():
    try:
        number = int(input("Enter a number: "))
    except ValueError:
        print("Error: Thtat is not a number")
    except KeyboardInterrupt:
        print("Error: Keyboard interrupt")

ask()
# Out:
# Error: Thtat is not a number

# %% [markdown]
# Extend the function from question 1 to include else and finally blocks, where else prints a success message and finally always prints a completion message.

# %%
def ask():
    try:
        number = int(input("Enter a number: "))
    except ValueError:
        print("Error: Thtat is not a number")
    else:
        print(number)
    finally:
        print("Done")

ask()
# Out:
# 18
# Done

# %% [markdown]
# Write a function that raises an exception with the message Number is negative if a user enters a negative number. If the exception is raised, print it.

# %%
def negative(x):
    if x < 0:
        raise ValueError("Negative number")
    else:
        return x
    
try:
    negative(-1)
except ValueError as e:
    print(e)
# Out:
# Negative number

# %% [markdown]
# Write a function that attempts to open a file provided by the user and print its contents. Use error handling to catch a FileNotFoundError and print a custom error message. Ensure the file is properly closed in a finally block if it was opened successfully.

# %%
def fileread():
    file = None
    try:
        filename = input("Enter filename")
        with open(filename, "r") as file:
            print(file.read())
    except FileNotFoundError:
        print("Error: File not found")
    finally:
        if file:
            file.close()

fileread()
# Out:
# Error: File not found

# %% [markdown]
# Given a list of mixed data types, write a function that prints each item if it's an integer. Use error handling to skip any item that raises a TypeError when cast to an integer.

# %%
def types(data):
    for item in data:
        try:
            print(int(item))
        except ValueError:
            continue

types([1, 2, "a", 4, 'b'])
# Out:
# 1
# 2
# 4

# %% [markdown]
# Write a function that takes a list of numbers and returns the sum. If the list contains a non-numeric type, catch the exception that would be raised by the sum function and return None instead.

# %%
def sumnum(nums):
    try:
        return sum(nums)
    except TypeError:
        return None
    
print(sumnum([1,2, "alex"]))
# Out:
# None

# %% [markdown]
# Write a function that divides two numbers provided by the user, handling division by zero and non-numeric input exceptions. It should return the division result or an appropriate error message.

# %%
def divide():
    try:
        a = float(input("Enter number 1: "))
        b = float(input("Enter number 2: "))
        result = a / b
    except ZeroDivisionError:
        print("Error: Can not divide by zero.")
    except ValueError:
        print("Error: Non-numeric value")
    else:
        print(f"Result {result}")

divide()
# Out:
# Error: Can not divide by zero.

# %% [markdown]
# Write a script that iterates over a list of URLs, attempting to fetch the content of each URL using urllib.request.urlopen. Use error handling to print a message for each URL that cannot be fetched, continuing with the next URL in the list.

# %%
import urllib

def fetch_urls(urls):
    for url in urls:
        try:
            response = urllib.request.urlopen(url)
            print (response.read())
        except Exception as e:
            print(f"Failed to fetch {url}: {e}")

fetch_urls(["https://google.com", "https://www.ada.com", "htp://maszniew"])
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="mt"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="PfJVW11_vNPA_N6CqUj2mQ">(function(){var _g={kEI:\'5FMaaODrLLW2hbIP76jL6A8\',kEXPI:\'0,202792,3497542,608,129,313,538661,48791,30022,6514,9591,344796,238459,51585,15664,5226017,108,85,5991636,26777105,29272390,164325,53220,6757,23880,9138,4599,328,6226,1116,49460,3613,9976,15049,15634,108816,4105,353,18880,8970,756,3858,5773,4310,6424,1852,3,893,1549,1621,143,8155,2662,7268,7622,1634,2808,453,458,2532,35,3420,2827,2841,1979,955,4881,570,1871,2321,4596,2195,201,354,658,609,4416,3604,7085,1438,4624,4625,2975,617,987,8,1,1,3,440,1175,2955,1129,600,1010,123,716,5,3427,131,2,1,2,2,2,3,1684,1281,1901,2,1596,679,13,3,4272,263,300,322,1610,486,1,617,623,1367,832,692,4,1475,1163,2277,199,574,622,1,756,919,2,1790,2,2198,598,258,4,1054,1,75,7,391,538,70,244,492,211,203,696,64,94,1579,1091,2,1153,1137,917,52,736,2,2556,117,3,86,145,2351,64,382,369,460,444,186,272,961,350,21,205,538,215,4,293,398,44,1,1,807,308,124,2,3,6,68,98,54,57,185,178,228,20,1,6,80,326,29,319,255,224,151,538,75,20,33,2,655,52,224,482,297,298,542,9,96,4,33,48,46,228,10,206,224,141,130,76,462,594,190,48,17,235,162,378,60,245,1328,310,21,57,434,125,2,567,571,562,113,292,744,1116,40,19,185,515,2,625,2,873,424,20878525,375837,4,28852,18,8725,240,6,1216,1182,5,2008,984,4,5892,108,881,3,412,15,463,94,1389,26,564,241,377,482,147,1433,495,8499494\',kBL:\'tylp\',kOPI:89978449};(function(){var a;((a=window.google)==null?0:a.stvsc)?google.kEI=_g.kEI:window.google=_g;}).call(this);})();(function(){google.sn=\'webhp\';google.kHL=\'mt\';})();(function(){\nvar g=this||self;function k(){return window.google&&window.google.kOPI||null};var l,m=[];function n(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||l}function p(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b}function q(a){/^http:/i.test(a)&&window.location.protocol==="https:"&&(google.ml&&google.ml(Error("a"),!1,{src:a,glmm:1}),a="");return a}\nfunction r(a,b,d,c,h){var e="";b.search("&ei=")===-1&&(e="&ei="+n(c),b.search("&lei=")===-1&&(c=p(c))&&(e+="&lei="+c));var f=b.search("&cshid=")===-1&&a!=="slh";c="&zx="+Date.now().toString();g._cshid&&f&&(c+="&cshid="+g._cshid);(d=d())&&(c+="&opi="+d);return"/"+(h||"gen_204")+"?atyp=i&ct="+String(a)+"&cad="+(b+e+c)};l=google.kEI;google.getEI=n;google.getLEI=p;google.ml=function(){return null};google.log=function(a,b,d,c,h,e){e=e===void 0?k:e;d||(d=r(a,b,e,c,h));if(d=q(d)){a=new Image;var f=m.length;m[f]=a;a.onerror=a.onload=a.onabort=function(){delete m[f]};a.src=d}};google.logUrl=function(a,b){b=b===void 0?k:b;return r("",a,b)};}).call(this);(function(){google.y={};google.sy=[];var d;(d=google).x||(d.x=function(a,b){if(a)var c=a.id;else{do c=Math.random();while(google.y[c])}google.y[c]=[a,b];return!1});var e;(e=google).sx||(e.sx=function(a){google.sy.push(a)});google.lm=[];var f;(f=google).plm||(f.plm=function(a){google.lm.push.apply(google.lm,a)});google.lq=[];var g;(g=google).load||(g.load=function(a,b,c){google.lq.push([[a],b,c])});var h;(h=google).loadAll||(h.loadAll=function(a,b){google.lq.push([a,b])});google.bx=!1;var k;(k=google).lx||(k.lx=function(){});var l=[],m;(m=google).fce||(m.fce=function(a,b,c,n){l.push([a,b,c,n])});google.qce=l;}).call(this);google.f={};(function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a=c==="1"||c==="q"&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if(a.tagName==="A"){a=a.getAttribute("data-nohref")==="1";break a}a=!1}a&&b.prevent ...
# Failed to fetch https://www.ada.com: HTTP Error 403: Forbidden
# Failed to fetch htp://maszniew: <urlopen error unknown url type: htp>

# %% [markdown]
# Write a function that takes a dictionary and a list of keys, attempting to print the value for each key. Use error handling to catch and print a message for any key that doesn't exist in the dictionary, without stopping the script.

# %%
def keysdic(data, keys):
    for key in keys:
        try:
            print(data[key])
        except KeyError:
            print(f"Key {key} not found")

keysdic({"a": 1, "b" : 2}, ["b", "c"])
# Out:
# 2
# Key c not found

# %% [markdown]
# Write a script that uses the datetime module to parse a list of date strings into datetime objects. Use error handling to catch and print an error message for any strings that are in an incorrect format, skipping over them.

# %%
from datetime import datetime

def parse(dates):
    for date_str in dates:
        try:
            parsed_date = datetime.strptime(date_str, "%Y-%m-%d")
            print(parsed_date)
        except ValueError:
            print(f"Error: {date_str} is not in the correct format")


parse(["2025-06-07", "notadate", "123456789"])
# Out:
# 2025-06-07 00:00:00
# Error: notadate is not in the correct format
# Error: 123456789 is not in the correct format
