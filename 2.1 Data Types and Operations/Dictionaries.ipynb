# %%
game = {
    "title" : "Fortnite",
    "price" : 10,
    "platforms": ["PC", "EpicGames"]
}

# %%
print (game["price"]*0.9)
# Out:
# 9.0

# %%
game["rating"] = 8.4
game["year_released"] = 2017

# %%
del(game["platforms"])

# %%
print(game)
# Out:
# {'title': 'Fortnite', 'price': 10, 'rating': 8.4, 'year_released': 2017}

# %%
print(game.keys())
# Out:
# dict_keys(['title', 'price', 'rating', 'year_released'])

# %%
game_list = []

# %%
game_list = list(game.values())
print(game_list)
# Out:
# ['Fortnite', 10, 8.4, 2017]

# %%
game_additional = {
    "publisher" : "EpicGames",
    "dlc_available": True
}

# %%
game.update(game_additional)
print(game)
# Out:
# {'title': 'Fortnite', 'price': 10, 'rating': 8.4, 'year_released': 2017, 'publisher': 'EpicGames', 'dlc_available': True}
