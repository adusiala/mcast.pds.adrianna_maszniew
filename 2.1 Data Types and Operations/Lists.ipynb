# %%
details = ['Adrianna', 20, ['Swimming', 'Music', 'Hiking']]

# %%
print('My age is' + ' ' + str(details[1]))
# Out:
# My age is 20

# %%
print(details[2][-1])
# Out:
# Hiking

# %%
details.append('adrianna.maszniew@gmail.com')

# %%
print(details)
# Out:
# ['Adrianna', 20, ['Swimming', 'Music', 'Hiking'], 'adrianna.maszniew@gmail.com']

# %%
details[2].append('Painting')
print(details)
# Out:
# ['Adrianna', 20, ['Swimming', 'Music', 'Hiking', 'Painting'], 'adrianna.maszniew@gmail.com']

# %%
details_copy = []

# %%
for item in details:
    details_copy.append(item)

print(details_copy)
# Out:
# ['Adrianna', 20, ['Swimming', 'Music', 'Hiking', 'Painting'], 'adrianna.maszniew@gmail.com']

# %%
details_copy.pop()
# Out:
# 'adrianna.maszniew@gmail.com'

# %%
print ("I have " + str(len(details_copy[2])) + " hobbies")
# Out:
# I have 4 hobbies

# %%
details_copy.sort(key=str)
print (details_copy)
# Out:
# [20, 'Adrianna', ['Swimming', 'Music', 'Hiking', 'Painting']]
